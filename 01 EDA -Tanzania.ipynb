# %% [markdown]
# ## Data Cleaning and EDA

# %%
#Batch Imports
import pandas as pd
import os
import re
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.display import display
pd.options.display.max_columns = None
sns.set(style="ticks")
seed=42
import pickle

# %%
# Import Datasets
X_train = pd.read_csv('./data/train_tanzania.csv')
y_train = pd.read_csv('./data/train_label_tanzania.csv')
X_test = pd.read_csv('./data/test_set_tanzania.csv')

# %%
X_train.head(5)
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  \
# 0  34.938093  -9.856322                  none            0
# 1  34.698766  -2.147466              Zahanati            0
# 2  37.460664  -3.821329           Kwa Mahundi            0
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4  31.130847  -1.825359               Shuleni            0
#
#                      basin  subvillage   region  region_code  district_code  \
# 0               Lake Nyasa    Mnyusi B   Iringa           11              5
# 1            Lake Victoria     Nyamara     Mara           20              2
# 2                  Pangani     Majengo  Manyara           21              4
# 3  Ruvuma / Southern Coast  Mahakamani   Mtwara           90             63
# 4            Lake Victoria  Kyanyamisa   Kagera           18              1
#
#          lga        ward  population public_meeting              recorded_by  \
# 0     Ludewa    Mundindi         109           True  GeoData Consultants Ltd
# 1  Serengeti       Natta         280            NaN  GeoData Consultants Ltd
# 2  Simanjiro     Ngorika         250           True  GeoData Consultants Ltd
# 3   Nanyumbu    Nanyumbu          58           True  GeoData Consultants Ltd
# 4    Karagwe  Nyakasimbi           0           True  GeoData Consultants Ltd
#
#   scheme_management                  scheme_name permit  construction_year  \
# 0               VWC                        Roman  False               1999
# 1             Other                          NaN   True               2010
# 2               VWC  Nyumba ya mungu pipe scheme   True               2009
# 3               VWC                          NaN   True               1986
# 4               NaN                          NaN   True                  0
#
#   extraction_type extraction_type_group extraction_type_class management  \
# 0         gravity               gravity               gravity        vwc
# 1         gravity               gravity               gravity        wug
# 2         gravity               gravity               gravity        vwc
# 3     submersible           submersible           submersible        vwc
# 4         gravity               gravity               gravity      other
#
#   management_group         payment payment_type water_quality quality_group  \
# 0       user-group    pay annually     annually          soft          good
# 1       user-group       never pay    never pay          soft          good
# 2       user-group  pay per bucket   per bucket          soft          good
# 3       user-group       never pay    never pay          soft          good
# 4            other       never pay    never pay          soft          good
#
#        quantity quantity_group                source           source_type  \
# 0        enough         enough                spring                spring
# 1  insufficient   insufficient  rainwater harvesting  rainwater harvesting
# 2        enough         enough                   dam                   dam
# 3           dry            dry           machine dbh              borehole
# 4      seasonal       seasonal  rainwater harvesting  rainwater harvesting
#
#   source_class              waterpoint_type waterpoint_type_group
# 0  groundwater           communal standpipe    communal standpipe
# 1      surface           communal standpipe    communal standpipe
# 2      surface  communal standpipe multiple    communal standpipe
# 3  groundwater  communal standpipe multiple    communal standpipe
# 4      surface           communal standpipe    communal standpipe

# %%
X_train.shape,y_train.shape
# Out:
# ((59400, 40), (59400, 2))

# %%
y_train.head(5)
# Out:
#       id    status_group
# 0  69572      functional
# 1   8776      functional
# 2  34310      functional
# 3  67743  non functional
# 4  19728      functional

# %% [markdown]
# ### For streamlined EDA, both independent variable sets were combined
# #### randomized shuffling will be conducted later when re splitting fo TTS

# %%
df_X=pd.merge(X_train,y_train, on='id')

# %%
df = df_X.append(X_test, ignore_index = True)
# Out:
# /Users/admin/anaconda3/envs/dsi/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
print("Dataset has {} rows, {} columns.".format(*df.shape))
# Out:
# Dataset has 74250 rows, 41 columns.

# %%
def eda(dataframe): #Credit: Ritika Bhasker, DSI alum
    print ("missing values \n", dataframe.isnull().sum())
    print("")
    print ("dataframe types \n", dataframe.dtypes)
    print("")
    print ("dataframe unique vals \n", dataframe.nunique())
    
eda(df)
# Out:
# missing values
#  amount_tsh                   0
# basin                        0
# construction_year            0
# date_recorded                0
# district_code                0
# extraction_type              0
# extraction_type_class        0
# extraction_type_group        0
# funder                    4504
# gps_height                   0
# id                           0
# installer                 4532
# latitude                     0
# lga                          0
# longitude                    0
# management                   0
# management_group             0
# num_private                  0
# payment                      0
# payment_type                 0
# permit                    3793
# population                   0
# public_meeting            4155
# quality_group                0
# quantity                     0
# quantity_group               0
# recorded_by                  0
# region                       0
# region_code                  0
# scheme_management         4846
# scheme_name              35258
# source                       0
# source_class                 0
# source_type                  0
# status_group             14850
# subvillage                 470
# ward                         0
# water_quality                0
# waterpoint_type              0
# waterpoint_type_group        0
# wpt_name                     0
# dtype: int64
#
# dataframe types
#  amount_tsh               float64
# basin                     object
# construction_year          int64
# date_recorded             object
# district_code              int64
# extraction_type           object
# extraction_type_class     object
# extraction_type_group     object
# funder                    object
# gps_height                 int64
# id                         int64
# installer                 object
# latitude                 float64
# lga                       object
# longitude                float64
# management                object
# management_group          object
# num_private                int64
# payment                   object
# payment_type              object
# permit                    object
# population                 int64
# public_meeting            object
# quality_group             object
# quantity                  object
# quantity_group            object
# recorded_by               object
# region                    object
# region_code                int64
# scheme_management         object
# scheme_name               object
# source                    object
# source_class              object
# source_type               object
# status_group              object
# subvillage                object
# ward                      object
# water_quality             object
# waterpoint_type           object
# waterpoint_type_group     object
# wpt_name                  object
# dtype: object
#
# dataframe unique vals
#  amount_tsh                 102
# basin                        9
# construction_year           55
# date_recorded              369
# district_code               20
# extraction_type             18
# extraction_type_class        7
# extraction_type_group       13
# funder                    2140
# gps_height                2456
# id                       74250
# installer                 2410
# latitude                 71869
# lga                        125
# longitude                71870
# management                  12
# management_group             5
# num_private                 68
# payment                      7
# payment_type                 7
# permit                       2
# population                1128
# public_meeting               2
# quality_group                6
# quantity                     5
# quantity_group               5
# recorded_by                  1
# region                      21
# region_code                 27
# scheme_management           12
# scheme_name               2868
# source                      10
# source_class                 3
# source_type                  7
# status_group                 3
# subvillage               21425
# ward                      2098
# water_quality                8
# waterpoint_type              7
# waterpoint_type_group        6
# wpt_name                 45684
# dtype: int64

# %%
# seperate features into numeric and categorical 
def identify_features():
    obs = df.select_dtypes(include=['object']).columns

    num = df.select_dtypes(include=[np.number]).columns

    print('There are {} categorical features'.format(len(obs)))
    print(obs)

    print('\n There are {} numerical features'.format(len(num)))
    return(obs,num)

# %%
cat,num = identify_features()
# Out:
# There are 31 categorical features
# Index(['basin', 'date_recorded', 'extraction_type', 'extraction_type_class',
#        'extraction_type_group', 'funder', 'installer', 'lga', 'management',
#        'management_group', 'payment', 'payment_type', 'permit',
#        'public_meeting', 'quality_group', 'quantity', 'quantity_group',
#        'recorded_by', 'region', 'scheme_management', 'scheme_name', 'source',
#        'source_class', 'source_type', 'status_group', 'subvillage', 'ward',
#        'water_quality', 'waterpoint_type', 'waterpoint_type_group',
#        'wpt_name'],
#       dtype='object')
#
#  There are 10 numerical features

# %%
cat
# Out:
# Index(['basin', 'date_recorded', 'extraction_type', 'extraction_type_class',
#        'extraction_type_group', 'funder', 'installer', 'lga', 'management',
#        'management_group', 'payment', 'payment_type', 'permit',
#        'public_meeting', 'quality_group', 'quantity', 'quantity_group',
#        'recorded_by', 'region', 'scheme_management', 'scheme_name', 'source',
#        'source_class', 'source_type', 'status_group', 'subvillage', 'ward',
#        'water_quality', 'waterpoint_type', 'waterpoint_type_group',
#        'wpt_name'],
#       dtype='object')

# %%
# visually identify the duplicated columns
df[cat].sample(n=12, random_state=42)
# Out:
#                          basin date_recorded extraction_type  \
# 66920            Lake Victoria    2013-01-26         afridev
# 7873                   Pangani    2011-03-05         gravity
# 8667                    Rufiji    2011-04-12         gravity
# 71951  Ruvuma / Southern Coast    2013-01-19            mono
# 29926               Lake Nyasa    2011-03-27     nira/tanira
# 19838                   Rufiji    2011-04-02         gravity
# 59897               Lake Nyasa    2013-02-14          swn 80
# 69927               Lake Nyasa    2011-04-08           other
# 9082                    Rufiji    2011-10-04         gravity
# 60312                 Internal    2013-02-19     nira/tanira
# 30004                  Pangani    2013-03-26         gravity
# 44534            Lake Victoria    2012-10-23         gravity
#
#       extraction_type_class extraction_type_group                  funder  \
# 66920              handpump               afridev                 Marafip
# 7873                gravity               gravity  Government Of Tanzania
# 8667                gravity               gravity                  Danida
# 71951             motorpump                  mono  Government Of Tanzania
# 29926              handpump           nira/tanira                     NaN
# 19838               gravity               gravity         Village Council
# 59897              handpump                swn 80                  Danida
# 69927                 other                 other  Government Of Tanzania
# 9082                gravity               gravity                  Unicef
# 60312              handpump           nira/tanira                     NaN
# 30004               gravity               gravity            World Vision
# 44534               gravity               gravity  Government Of Tanzania
#
#                        installer            lga  management management_group  \
# 66920                        DWE          Bunda         wug       user-group
# 7873                         DWE        Lushoto         vwc       user-group
# 8667                      DANIDA    Mbeya Rural         wug       user-group
# 71951  District Water Department     Nachingwea         vwc       user-group
# 29926                        NaN          Ileje         vwc       user-group
# 19838            VILLAGE COUNCIL    Mbeya Rural         wug       user-group
# 59897                     DANIDA       Namtumbo         wug       user-group
# 69927           Village  Council    Mbeya Rural  parastatal       parastatal
# 9082                         DWE         Njombe         wua       user-group
# 60312                        NaN  Singida Rural         vwc       user-group
# 30004                        DWE   Arusha Rural         vwc       user-group
# 44534                 Government   Musoma Rural         vwc       user-group
#
#                      payment payment_type permit public_meeting quality_group  \
# 66920  pay when scheme fails   on failure  False           True          good
# 7873               never pay    never pay   True           True          good
# 8667   pay when scheme fails   on failure  False          False          good
# 71951         pay per bucket   per bucket  False           True       unknown
# 29926                unknown      unknown  False           True          good
# 19838            pay monthly      monthly   True           True          good
# 59897            pay monthly      monthly  False           True          good
# 69927  pay when scheme fails   on failure  False          False          good
# 9082             pay monthly      monthly   True           True          good
# 60312  pay when scheme fails   on failure    NaN           True          good
# 30004              never pay    never pay   True           True          good
# 44534                unknown      unknown  False            NaN          good
#
#            quantity quantity_group              recorded_by   region  \
# 66920        enough         enough  GeoData Consultants Ltd     Mara
# 7873         enough         enough  GeoData Consultants Ltd    Tanga
# 8667         enough         enough  GeoData Consultants Ltd    Mbeya
# 71951           dry            dry  GeoData Consultants Ltd    Lindi
# 29926      seasonal       seasonal  GeoData Consultants Ltd    Mbeya
# 19838        enough         enough  GeoData Consultants Ltd    Mbeya
# 59897        enough         enough  GeoData Consultants Ltd   Ruvuma
# 69927      seasonal       seasonal  GeoData Consultants Ltd    Mbeya
# 9082   insufficient   insufficient  GeoData Consultants Ltd   Iringa
# 60312  insufficient   insufficient  GeoData Consultants Ltd  Singida
# 30004  insufficient   insufficient  GeoData Consultants Ltd   Arusha
# 44534        enough         enough  GeoData Consultants Ltd     Mara
#
#       scheme_management                  scheme_name                source  \
# 66920               WUG                          NaN          shallow well
# 7873                VWC                Shagai streem                spring
# 8667                VWC                          NaN                 river
# 71951               VWC                 Chimbendenga           machine dbh
# 29926               VWC                          NaN          shallow well
# 19838               VWC                          NaN                 river
# 59897               WUG                          NaN          shallow well
# 69927        Parastatal                          NaN  rainwater harvesting
# 9082                WUA  wanging'ombe water supply s                 river
# 60312               VWC                          NaN          shallow well
# 30004               VWC          Lemanyata pipe line                spring
# 44534               VWC                          NaN                   dam
#
#       source_class           source_type             status_group  \
# 66920  groundwater          shallow well                      NaN
# 7873   groundwater                spring               functional
# 8667       surface            river/lake               functional
# 71951  groundwater              borehole                      NaN
# 29926  groundwater          shallow well               functional
# 19838      surface            river/lake               functional
# 59897  groundwater          shallow well                      NaN
# 69927      surface  rainwater harvesting                      NaN
# 9082       surface            river/lake  functional needs repair
# 60312  groundwater          shallow well                      NaN
# 30004  groundwater                spring           non functional
# 44534      surface                   dam           non functional
#
#          subvillage      ward water_quality              waterpoint_type  \
# 66920      Mwilindi   Kisorya          soft                    hand pump
# 7873        Mgwashi   Mbaramo          soft           communal standpipe
# 8667          Itete    Ilungu          soft           communal standpipe
# 71951  Nyerere Road    Mbondo       unknown  communal standpipe multiple
# 29926         Isoka     Mbebe          soft                    hand pump
# 19838      Simambwe     Igale          soft           communal standpipe
# 59897      Ngongoma   Kitanda          soft                    hand pump
# 69927        Mafune    Ilembo          soft                        other
# 9082          Itula     Usuka          soft           communal standpipe
# 60312    Mampando A    Ntuntu          soft                    hand pump
# 30004            Rc  Olkokola          soft           communal standpipe
# 44534     Kamimange   Butiama          soft  communal standpipe multiple
#
#       waterpoint_type_group            wpt_name
# 66920             hand pump          Kwa Manjar
# 7873     communal standpipe     Kwa Mzee Timoni
# 8667     communal standpipe         Kwa Mvulula
# 71951    communal standpipe             Shuleni
# 29926             hand pump           Kwaibhare
# 19838    communal standpipe        Daima Sekele
# 59897             hand pump           Kwa Kauti
# 69927                 other      Kituo Cha Afya
# 9082     communal standpipe           Kwa Mbugi
# 60312             hand pump       Yusuphu Athum
# 30004    communal standpipe       Kwa Mama Mage
# 44534    communal standpipe  Kwa Mzee Koronzomo

# %%
df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# scheme_name          35258
# status_group         14850
# scheme_management     4846
# installer             4532
# funder                4504
# public_meeting        4155
# permit                3793
# subvillage             470
# district_code            0
# extraction_type          0
# dtype: int64

# %%
# drop excess features
df.drop(['scheme_name','source','payment','quantity',
         'waterpoint_type','scheme_management','public_meeting',
         'permit','extraction_type','region_code'],axis=1, inplace=True)

# %%
#drop rows with any null values in these columns 
df=df.dropna(subset=['funder','installer','subvillage'], how='any')

# %%
df.isnull().sum()
# Out:
# amount_tsh                   0
# basin                        0
# construction_year            0
# date_recorded                0
# district_code                0
# extraction_type_class        0
# extraction_type_group        0
# funder                       0
# gps_height                   0
# id                           0
# installer                    0
# latitude                     0
# lga                          0
# longitude                    0
# management                   0
# management_group             0
# num_private                  0
# payment_type                 0
# permit                     799
# population                   0
# quality_group                0
# quantity_group               0
# recorded_by                  0
# region                       0
# region_code                  0
# source_class                 0
# source_type                  0
# status_group             13862
# subvillage                   0
# ward                         0
# water_quality                0
# waterpoint_type_group        0
# wpt_name                     0
# dtype: int64

# %%
df.shape

# %% [markdown]
# ### Numerical Data

# %%
df[num].describe()
# Out:
#           amount_tsh  construction_year  district_code    gps_height  \
# count   69183.000000       69183.000000   69183.000000  69183.000000
# mean      331.272965        1345.086264       5.643858    679.693595
# std      2685.105337         936.494643       9.643272    691.269334
# min         0.000000           0.000000       0.000000    -90.000000
# 25%         0.000000           0.000000       2.000000      0.000000
# 50%         0.000000        1988.000000       3.000000    401.000000
# 75%        30.000000        2005.000000       5.000000   1317.000000
# max    250000.000000        2013.000000      80.000000   2777.000000
#
#                  id      latitude     longitude   num_private    population  \
# count  69183.000000  6.918300e+04  69183.000000  69183.000000  69183.000000
# mean   37138.483833 -5.618044e+00     34.040217      0.492361    188.831360
# std    21434.201096  2.960383e+00      6.764853     11.933675    479.438286
# min        0.000000 -1.164944e+01      0.000000      0.000000      0.000000
# 25%    18570.500000 -8.257811e+00     33.005367      0.000000      0.000000
# 50%    37141.000000 -4.900364e+00     35.028777      0.000000     40.000000
# 75%    55696.500000 -3.300273e+00     37.295202      0.000000    234.000000
# max    74249.000000 -2.000000e-08     40.345193   1776.000000  30500.000000
#
#         region_code
# count  69183.000000
# mean      15.493430
# std       17.922556
# min        1.000000
# 25%        5.000000
# 50%       12.000000
# 75%       17.000000
# max       99.000000

# %%
df.region_code.value_counts(normalize=True).head(10)
# Out:
# 11    0.095284
# 17    0.090658
# 3     0.079311
# 5     0.073212
# 18    0.058454
# 19    0.054204
# 16    0.050894
# 12    0.048336
# 2     0.047815
# 10    0.047743
# Name: region_code, dtype: float64

# %%
df.district_code.value_counts(normalize=True).head(10)
# Out:
# 1     0.216874
# 2     0.182877
# 3     0.171545
# 4     0.142419
# 5     0.074296
# 6     0.071130
# 7     0.048466
# 8     0.018487
# 30    0.018097
# 33    0.015307
# Name: district_code, dtype: float64

# %%
#convert district codes to categorical variables
df['district_code'] = df['district_code'].astype(str)

# %%
#correlation analysis see if any of the features are duplicates and therefore candidates for removal
df.corr()
# Out:
#                    amount_tsh  construction_year  gps_height        id  \
# amount_tsh           1.000000           0.076826    0.087688 -0.009580
# construction_year    0.076826           1.000000    0.636677 -0.002586
# gps_height           0.087688           0.636677    1.000000 -0.003332
# id                  -0.009580          -0.002586   -0.003332  1.000000
# latitude            -0.068399          -0.329048   -0.088352  0.003569
# longitude            0.025502           0.418724    0.153083 -0.001597
# num_private          0.005891           0.026742    0.007079 -0.004652
# population           0.016414           0.258466    0.126425 -0.004808
#
#                    latitude  longitude  num_private  population
# amount_tsh        -0.068399   0.025502     0.005891    0.016414
# construction_year -0.329048   0.418724     0.026742    0.258466
# gps_height        -0.088352   0.153083     0.007079    0.126425
# id                 0.003569  -0.001597    -0.004652   -0.004808
# latitude           1.000000  -0.439390     0.004925   -0.038612
# longitude         -0.439390   1.000000     0.024955    0.088295
# num_private        0.004925   0.024955     1.000000    0.002941
# population        -0.038612   0.088295     0.002941    1.000000

# %%
df.isnull().sum()
# Out:
# amount_tsh                   0
# basin                        0
# construction_year            0
# date_recorded                0
# district_code                0
# extraction_type_class        0
# extraction_type_group        0
# funder                       0
# gps_height                   0
# id                           0
# installer                    0
# latitude                     0
# lga                          0
# longitude                    0
# management                   0
# management_group             0
# num_private                  0
# payment_type                 0
# population                   0
# quality_group                0
# quantity_group               0
# recorded_by                  0
# region                       0
# source_class                 0
# source_type                  0
# status_group             13862
# subvillage                   0
# ward                         0
# water_quality                0
# waterpoint_type_group        0
# wpt_name                     0
# dtype: int64

# %% [markdown]
# ### Seperate training and test sets

# %%
df_test= df[df['status_group'].isnull()]
df_test.drop('status_group',axis=1,inplace=True)
# Out:
# /Users/admin/anaconda3/envs/dsi/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
df_train=df.dropna(subset=['status_group'], how='any')

# %%
df_test.shape,df_train.shape

# %%
df_train.to_pickle('./data/train.pkl')
df_test.to_pickle('./data/test.pkl')
